# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

from citipy import citipy

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | atuona
# Processing Record 2 of Set 15 | sao filipe
# Processing Record 3 of Set 15 | muroto
# Processing Record 4 of Set 15 | chuy
# Processing Record 5 of Set 15 | arraial do cabo
# Processing Record 6 of Set 15 | aswan
# Processing Record 7 of Set 15 | albany
# Processing Record 8 of Set 15 | port alfred
# Processing Record 9 of Set 15 | flin flon
# Processing Record 10 of Set 15 | hobart
# Processing Record 11 of Set 15 | jamestown
# Processing Record 12 of Set 15 | rikitea
# Processing Record 13 of Set 15 | victoria
# Processing Record 14 of Set 15 | hanzhong
# Processing Record 15 of Set 15 | saint george
# Processing Record 16 of Set 15 | ambon
# Processing Record 17 of Set 15 | sabha
# Processing Record 18 of Set 15 | vaini
# Processing Record 19 of Set 15 | mataura
# Processing Record 20 of Set 15 | dunedin
# Processing Record 21 of Set 15 | lubumbashi
# Processing Record 22 of Set 15 | chokurdakh
# Processing Record 23 of Set 15 | mar del plata
# Processing Record 24 of Set 15 | yulara
# Processing Record 25 of Set 15 | shahr-e kord
# Processing Record 26 of Set 15 | busselton
# Processing Record 27 of Set 15 | mahebourg
# Processing Record 28 of Set 15 | kutum
# Processing Record 29 of Set 15 | hermanus
# Processing Record 30 of Set 15 | namatanai
# Processing Record 31 of Set 15 | viana
# Processing Record 32 of Set 15 | sola
# Processing Record 33 of Set 15 | provideniya
# Processing Record 34 of Set 15 | upernavik
# Processing Record 35 of Set 15 | ushuaia
# Processing Record 36 of Set 15 | yakima
# Processing Record 37 of Set 15 | mutis
# Processing Record 38 of Set 15 | venado tuerto
# Processing Record 39 of Set 15 | cabo san lucas
# Processing Record 40 of Set 15 | qaanaaq
# Processing Record 41 of Set 15 | longyearbyen
# Processing Record 42 of Set 15 | hilo
# Processing Record 43 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 15 | mogadishu
# Processing Record 45 of Set 15 | khatanga
# Processing Record 46 of Set 15 | punta arenas
# Processing Record 47 of Set 15 | cabedelo
# Processing Record 48 of Set 15 | bredasdorp
# Processing Record 49 of Set 15 | butaritari
# Processing Record 50 of Set 15 | wewak
# Processing Record 1 of Set 16 | nedjo
# Processing Record 2 of Set 16 | tay ninh
# Processing Record 3 of Set 16 | tautira
# Processing Record 4 of Set 16 | natal
# Processing Record 5 of Set 16 | karpogory
# Processing Record 6 of Set 16 | torbay
# Processing Record 7 of Set 16 | ossora
# Processing Record 8 of Set 16 | erdenet
# Processing Record 9 of Set 16 | komsomolskiy
# Processing Record 10 of Set 16 | saint anthony
# Processing Record 11 of Set 16 | sitka
# Processing Record 12 of Set 16 | pisco
# Processing Record 13 of Set 16 | krasnoselkup
# Processing Record 14 of Set 16 | constitucion
# Processing Record 15 of Set 16 | egvekinot
# Processing Record 16 of Set 16 | hobyo
# Processing Record 17 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 16 | inhambane
# Processing Record 19 of Set 16 | estelle
# Processing Record 20 of Set 16 | norman wells
# Processing Record 21 of Set 16 | new norfolk
# Processing Record 22 of Set 16 | zhaotong
# Processing Record 23 of Set 16 | jardim
# Processing Record 24 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 16 | niamey
# Processing Record 26 of Set 16 | cape town
# Processing Record 27 of Set 16 | avarua
# Processing Record 28 of Set 16 | araouane
# Processing Record 29 of Set 16 | melilla
# Processing Record 30 of Set 16 | havre-saint-pierre
# Processing Record 31 of Set 16 | gizo
# Processing Record 32 of Set 16 | yellowknife
# Processing Record 33 of Set 16 | kalianget
# Processing Record 34 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 16 | maragogi
# Processing Record 36 of Set 16 | airai
# Processing Record 37 of Set 16 | ampanihy
# Processing Record 38 of Set 16 | zavitinsk
# Processing Record 39 of Set 16 | cidreira
# Processing Record 40 of Set 16 | kapaa
# Processing Record 41 of Set 16 | bluff
# Processing Record 42 of Set 16 | hithadhoo
# Processing Record 43 of Set 16 | barrow
# Processing Record 44 of Set 16 | alugan
# Processing Record 45 of Set 16 | codrington
# Processing Record 46 of Set 16 | ylivieska
# Processing Record 47 of Set 16 | valdosta
# Processing Record 48 of Set 16 | dikson
# Processing Record 49 of Set 16 | atherton
# Processing Record 50 of Set 16 | talnakh
# Processing Record 1 of Set 17 | termiz
# Processing Record 2 of Set 17 | chengde
# Processing Record 3 of Set 17 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 17 | san cristobal
# Processing Record 5 of Set 17 | beringovskiy
# Processing Record 6 of Set 17 | gat
# Processing Record 7 of Set 17 | saldanha
# Processing Record 8 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 17 | oriximina
# Processing Record 10 of Set 17 | east london
# Processing Record 11 of Set 17 | wuxue
# Processing Record 12 of Set 17 | sibolga
# Processing Record 13 of Set 17 | tutoia
# Processing Record 14 of Set 17 | kismayo
# Processing Record 15 of Set 17 | siruguppa
# Processing Record 16 of Set 17 | puerto ayora
# Processing Record 17 of Set 17 | biak
# Processing Record 18 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 17 | grindavik
# Processing Record 20 of Set 17 | georgetown
# Processing Record 21 of Set 17 | san carlos de bariloche
# Processing Record 22 of Set 17 | praxedis guerrero
# Processing Record 23 of Set 17 | bethel
# Processing Record 24 of Set 17 | gazanjyk
# Processing Record 25 of Set 17 | rehoboth
# Processing Record 26 of Set 17 | souillac
# Processing Record 27 of Set 17 | goulburn
# Processing Record 28 of Set 17 | vilhena
# Processing Record 29 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 17 | severo-kurilsk
# Processing Record 31 of Set 17 | khor
# Processing Record 32 of Set 17 | nikolskoye
# Processing Record 33 of Set 17 | pushkino
# Processing Record 34 of Set 17 | iqaluit
# Processing Record 35 of Set 17 | castro
# Processing Record 36 of Set 17 | pudozh
# Processing Record 37 of Set 17 | spornoye
# Processing Record 38 of Set 17 | maldegem
# Processing Record 39 of Set 17 | ribeira grande
# Processing Record 40 of Set 17 | bokoro
# Processing Record 41 of Set 17 | chachapoyas
# Processing Record 42 of Set 17 | sibu
# Processing Record 43 of Set 17 | rocha
# Processing Record 44 of Set 17 | baruun-urt
# Processing Record 45 of Set 17 | yumen
# Processing Record 46 of Set 17 | cherskiy
# Processing Record 47 of Set 17 | saint-philippe
# Processing Record 48 of Set 17 | iralaya
# Processing Record 49 of Set 17 | bang saphan
# Processing Record 50 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 18 | guozhen
# Processing Record 2 of Set 18 | buala
# Processing Record 3 of Set 18 | sulangan
# Processing Record 4 of Set 18 | te anau
# Processing Record 5 of Set 18 | sorong
# Processing Record 6 of Set 18 | jaciara
# Processing Record 7 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 18 | evensk
# Processing Record 9 of Set 18 | carnarvon
# Processing Record 10 of Set 18 | rio gallegos
# Processing Record 11 of Set 18 | takestan
# Processing Record 12 of Set 18 | el tarra
# Processing Record 13 of Set 18 | tuktoyaktuk
# Processing Record 14 of Set 18 | padre bernardo
# Processing Record 15 of Set 18 | tucano
# Processing Record 16 of Set 18 | tzucacab
# Processing Record 17 of Set 18 | spencer
# Processing Record 18 of Set 18 | ketchikan
# Processing Record 19 of Set 18 | korla
# Processing Record 20 of Set 18 | arman
# Processing Record 21 of Set 18 | mezen
# Processing Record 22 of Set 18 | oranjemund
# Processing Record 23 of Set 18 | havelock
# Processing Record 24 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 18 | beloha
# Processing Record 26 of Set 18 | tasiilaq
# Processing Record 27 of Set 18 | haines junction
# Processing Record 28 of Set 18 | oxapampa
# Processing Record 29 of Set 18 | mount isa
# Processing Record 30 of Set 18 | chhatarpur
# Processing Record 31 of Set 18 | vila
# Processing Record 32 of Set 18 | saskylakh
# Processing Record 33 of Set 18 | constantine
# Processing Record 34 of Set 18 | taoudenni
# Processing Record 35 of Set 18 | keetmanshoop
# Processing Record 36 of Set 18 | polonnaruwa
# Processing Record 37 of Set 18 | palana
# Processing Record 38 of Set 18 | salvacion
# Processing Record 39 of Set 18 | micomeseng
# Processing Record 40 of Set 18 | wad rawah
# Processing Record 41 of Set 18 | morondava
# Processing Record 42 of Set 18 | kaura namoda
# Processing Record 43 of Set 18 | katsuura
# Processing Record 44 of Set 18 | henties bay
# Processing Record 45 of Set 18 | raudeberg
# Processing Record 46 of Set 18 | port lincoln
# Processing Record 47 of Set 18 | gari
# Processing Record 48 of Set 18 | bengkulu
# Processing Record 49 of Set 18 | sampit
# Processing Record 50 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 19 | caravelas
# Processing Record 2 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 19 | smithers
# Processing Record 4 of Set 19 | ust-tsilma
# Processing Record 5 of Set 19 | batagay
# Processing Record 6 of Set 19 | bambanglipuro
# Processing Record 7 of Set 19 | cody
# Processing Record 8 of Set 19 | bathsheba
# Processing Record 9 of Set 19 | san policarpo
# Processing Record 10 of Set 19 | north bend
# Processing Record 11 of Set 19 | cayenne
# Processing Record 12 of Set 19 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 19 | adelanto
# Processing Record 14 of Set 19 | begowal
# Processing Record 15 of Set 19 | jumla
# Processing Record 16 of Set 19 | damaturu
# Processing Record 17 of Set 19 | san clemente
# Processing Record 18 of Set 19 | leningradskiy
# Processing Record 19 of Set 19 | lagoa
# Processing Record 20 of Set 19 | porto novo
# Processing Record 21 of Set 19 | karratha
# Processing Record 22 of Set 19 | mbanza-ngungu
# Processing Record 23 of Set 19 | ginir
# Processing Record 24 of Set 19 | thompson
# Processing Record 25 of Set 19 | kharabali
# Processing Record 26 of Set 19 | snasa
# Processing Record 27 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 19 | kupang
# Processing Record 29 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 19 | grants
# Processing Record 31 of Set 19 | garden city
# Processing Record 32 of Set 19 | lebu
# Processing Record 33 of Set 19 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 19 | vila franca do campo
# Processing Record 35 of Set 19 | nelson bay
# Processing Record 36 of Set 19 | saint-augustin
# Processing Record 37 of Set 19 | methoni
# Processing Record 38 of Set 19 | college
# Processing Record 39 of Set 19 | cao bang
# Processing Record 40 of Set 19 | cap malheureux
# Processing Record 41 of Set 19 | narsaq
# Processing Record 42 of Set 19 | kaitangata
# Processing Record 43 of Set 19 | cabra
# Processing Record 44 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 19 | coahuayana
# Processing Record 46 of Set 19 | banda aceh
# Processing Record 47 of Set 19 | valparaiso
# Processing Record 48 of Set 19 | wainwright
# Processing Record 49 of Set 19 | neokhoropoulon
# City not found. Skipping...
# Processing Record 50 of Set 19 | okha
# Processing Record 1 of Set 20 | mayo
# Processing Record 2 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 20 | lom sak
# Processing Record 4 of Set 20 | kodiak
# Processing Record 5 of Set 20 | aporawan
# City not found. Skipping...
# Processing Record 6 of Set 20 | bima
# Processing Record 7 of Set 20 | ixtapa
# Processing Record 8 of Set 20 | paracuru
# Processing Record 9 of Set 20 | sayyan
# Processing Record 10 of Set 20 | avera
# Processing Record 11 of Set 20 | vitim
# Processing Record 12 of Set 20 | lata
# Processing Record 13 of Set 20 | kalemie
# Processing Record 14 of Set 20 | qaqortoq
# Processing Record 15 of Set 20 | port hardy
# Processing Record 16 of Set 20 | sioux lookout
# Processing Record 17 of Set 20 | half moon bay
# Processing Record 18 of Set 20 | vryburg
# Processing Record 19 of Set 20 | kavieng
# Processing Record 20 of Set 20 | turka
# Processing Record 21 of Set 20 | drovyanaya
# Processing Record 22 of Set 20 | port-gentil
# Processing Record 23 of Set 20 | ponta do sol
# Processing Record 24 of Set 20 | pevek
# Processing Record 25 of Set 20 | riberalta
# Processing Record 26 of Set 20 | phalaborwa
# Processing Record 27 of Set 20 | pangkalanbuun
# Processing Record 28 of Set 20 | russell
# Processing Record 29 of Set 20 | pak phanang
# Processing Record 30 of Set 20 | sorland
# Processing Record 31 of Set 20 | vanimo
# Processing Record 32 of Set 20 | clyde river
# Processing Record 33 of Set 20 | manakara
# Processing Record 34 of Set 20 | am timan
# Processing Record 35 of Set 20 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 20 | ilulissat
# Processing Record 37 of Set 20 | alice springs
# Processing Record 38 of Set 20 | karasburg
# Processing Record 39 of Set 20 | esperance
# Processing Record 40 of Set 20 | rome
# Processing Record 41 of Set 20 | lorengau
# Processing Record 42 of Set 20 | odweyne
# Processing Record 43 of Set 20 | hami
# Processing Record 44 of Set 20 | erzin
# Processing Record 45 of Set 20 | opuwo
# Processing Record 46 of Set 20 | nuuk
# Processing Record 47 of Set 20 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 20 | wuda
# Processing Record 49 of Set 20 | nueve de julio
# Processing Record 50 of Set 20 | terney
# Processing Record 1 of Set 21 | nanortalik
# Processing Record 2 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 21 | seoul
# Processing Record 4 of Set 21 | acari
# Processing Record 5 of Set 21 | yaan
# Processing Record 6 of Set 21 | bilma
# Processing Record 7 of Set 21 | neyshabur
# Processing Record 8 of Set 21 | touros
# Processing Record 9 of Set 21 | maceio
# Processing Record 10 of Set 21 | mount gambier
# Processing Record 11 of Set 21 | dunmore
# Processing Record 12 of Set 21 | naze
# Processing Record 13 of Set 21 | bambous virieux
# Processing Record 14 of Set 21 | luderitz
# Processing Record 15 of Set 21 | port elizabeth
# Processing Record 16 of Set 21 | labuhan
# Processing Record 17 of Set 21 | ciudad bolivar
# Processing Record 18 of Set 21 | tilichiki
# Processing Record 19 of Set 21 | play cu
# City not found. Skipping...
# Processing Record 20 of Set 21 | coihaique
# Processing Record 21 of Set 21 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 21 | brora
# Processing Record 23 of Set 21 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 24 of Set 21 | aklavik
# Processing Record 25 of Set 21 | lavrentiya
# Processing Record 26 of Set 21 | viesite
# Processing Record 27 of Set 21 | chhapar
# Processing Record 28 of Set 21 | sortland
# Processing Record 29 of Set 21 | kruisfontein
# Processing Record 30 of Set 21 | faya
# Processing Record 31 of Set 21 | chingirlau
# Processing Record 32 of Set 21 | sechura
# Processing Record 33 of Set 21 | klyuchi
# Processing Record 34 of Set 21 | geraldton
# Processing Record 35 of Set 21 | nishihara
# Processing Record 36 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 21 | koutsouras
# Processing Record 38 of Set 21 | yurla
# Processing Record 39 of Set 21 | sao jose do belmonte
# Processing Record 40 of Set 21 | straumen
# Processing Record 41 of Set 21 | siuna
# Processing Record 42 of Set 21 | garissa
# Processing Record 43 of Set 21 | dryden
# Processing Record 44 of Set 21 | richards bay
# Processing Record 45 of Set 21 | akhtanizovskaya
# Processing Record 46 of Set 21 | montrose
# Processing Record 47 of Set 21 | manoel urbano
# Processing Record 48 of Set 21 | coquimbo
# Processing Record 49 of Set 21 | ryuo
# Processing Record 50 of Set 21 | muros
# Processing Record 1 of Set 22 | lixourion
# Processing Record 2 of Set 22 | camacha
# Processing Record 3 of Set 22 | liyang
# Processing Record 4 of Set 22 | muzhi
# Processing Record 5 of Set 22 | vila do maio
# Processing Record 6 of Set 22 | lamin
# Processing Record 7 of Set 22 | faanui
# Processing Record 8 of Set 22 | north marysville
# City not found. Skipping...
# Processing Record 9 of Set 22 | champerico
# Processing Record 10 of Set 22 | amsterdam
# Processing Record 11 of Set 22 | isangel
# Processing Record 12 of Set 22 | anage
# Processing Record 13 of Set 22 | grand forks
# Processing Record 14 of Set 22 | flinders
# Processing Record 15 of Set 22 | portland
# Processing Record 16 of Set 22 | tuatapere
# Processing Record 17 of Set 22 | hongjiang
# Processing Record 18 of Set 22 | srednekolymsk
# Processing Record 19 of Set 22 | nome
# Processing Record 20 of Set 22 | port hedland
# Processing Record 21 of Set 22 | ambilobe
# Processing Record 22 of Set 22 | yagodnoye
# Processing Record 23 of Set 22 | williams lake
# Processing Record 24 of Set 22 | arkhara
# Processing Record 25 of Set 22 | mongu
# Processing Record 26 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 22 | phalodi
# Processing Record 28 of Set 22 | cavalcante
# Processing Record 29 of Set 22 | hofn
# Processing Record 30 of Set 22 | urumqi
# Processing Record 31 of Set 22 | opobo
# City not found. Skipping...
# Processing Record 32 of Set 22 | kahului
# Processing Record 33 of Set 22 | harper
# Processing Record 34 of Set 22 | dubbo
# Processing Record 35 of Set 22 | rio branco
# Processing Record 36 of Set 22 | lakes entrance
# Processing Record 37 of Set 22 | seydi
# Processing Record 38 of Set 22 | miquelon
# Processing Record 39 of Set 22 | severodvinsk
# Processing Record 40 of Set 22 | itaocara
# Processing Record 41 of Set 22 | kaeo
# Processing Record 42 of Set 22 | tessalit
# Processing Record 43 of Set 22 | raga
# Processing Record 44 of Set 22 | abbeville
# Processing Record 45 of Set 22 | tiksi
# Processing Record 46 of Set 22 | gambela
# Processing Record 47 of Set 22 | bolkhov
# Processing Record 48 of Set 22 | drabiv
# Processing Record 49 of Set 22 | bubaque
# Processing Record 50 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 23 | ostrovnoy
# Processing Record 2 of Set 23 | maxixe
# Processing Record 3 of Set 23 | riyadh
# Processing Record 4 of Set 23 | westport
# Processing Record 5 of Set 23 | kysyl-syr
# Processing Record 6 of Set 23 | mitu
# Processing Record 7 of Set 23 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 23 | alyangula
# Processing Record 9 of Set 23 | turmalina
# Processing Record 10 of Set 23 | nieuw amsterdam
# Processing Record 11 of Set 23 | tres picos
# Processing Record 12 of Set 23 | iracoubo
# Processing Record 13 of Set 23 | muromtsevo
# Processing Record 14 of Set 23 | fonte boa
# Processing Record 15 of Set 23 | nicolet
# Processing Record 16 of Set 23 | nago
# Processing Record 17 of Set 23 | rafai
# Processing Record 18 of Set 23 | solwezi
# Processing Record 19 of Set 23 | svetlaya
# Processing Record 20 of Set 23 | antofagasta
# Processing Record 21 of Set 23 | nagato
# Processing Record 22 of Set 23 | usolye
# Processing Record 23 of Set 23 | swellendam
# Processing Record 24 of Set 23 | gejiu
# Processing Record 25 of Set 23 | kasempa
# Processing Record 26 of Set 23 | cabo rojo
# Processing Record 27 of Set 23 | puerto cabezas
# Processing Record 28 of Set 23 | noumea
# Processing Record 29 of Set 23 | jacareacanga
# Processing Record 30 of Set 23 | salta
# Processing Record 31 of Set 23 | udachnyy
# Processing Record 32 of Set 23 | santa cruz del sur
# Processing Record 33 of Set 23 | hun
# Processing Record 34 of Set 23 | seguin
# Processing Record 35 of Set 23 | rawlins
# Processing Record 36 of Set 23 | kamina
# Processing Record 37 of Set 23 | hasaki
# Processing Record 38 of Set 23 | olafsvik
# Processing Record 39 of Set 23 | itarema
# Processing Record 40 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 23 | dera ghazi khan
# Processing Record 42 of Set 23 | taltal
# Processing Record 43 of Set 23 | babina
# Processing Record 44 of Set 23 | kibala
# Processing Record 45 of Set 23 | vardo
# Processing Record 46 of Set 23 | san antonio
# Processing Record 47 of Set 23 | mafra
# Processing Record 48 of Set 23 | asti
# Processing Record 49 of Set 23 | magnor
# Processing Record 50 of Set 23 | vila velha
# Processing Record 1 of Set 24 | vestmannaeyjar
# Processing Record 2 of Set 24 | cruzeiro do sul
# Processing Record 3 of Set 24 | phulji
# Processing Record 4 of Set 24 | sistranda
# Processing Record 5 of Set 24 | zyryanovsk
# Processing Record 6 of Set 24 | rabo de peixe
# Processing Record 7 of Set 24 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 24 | moose factory
# Processing Record 9 of Set 24 | fortuna
# Processing Record 10 of Set 24 | kawalu
# Processing Record 11 of Set 24 | marovoay
# Processing Record 12 of Set 24 | namibe
# Processing Record 13 of Set 24 | nouakchott
# Processing Record 14 of Set 24 | olga
# Processing Record 15 of Set 24 | gazojak
# Processing Record 16 of Set 24 | sovetskiy
# Processing Record 17 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 24 | ures
# Processing Record 19 of Set 24 | tiarei
# Processing Record 20 of Set 24 | marquette
# Processing Record 21 of Set 24 | boende
# Processing Record 22 of Set 24 | winnemucca
# Processing Record 23 of Set 24 | at-bashi
# Processing Record 24 of Set 24 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 24 | coos bay
# Processing Record 26 of Set 24 | bashmakovo
# Processing Record 27 of Set 24 | sangar
# Processing Record 28 of Set 24 | pingzhuang
# Processing Record 29 of Set 24 | sambava
# Processing Record 30 of Set 24 | kurilsk
# Processing Record 31 of Set 24 | altamont
# Processing Record 32 of Set 24 | eha amufu
# Processing Record 33 of Set 24 | benghazi
# Processing Record 34 of Set 24 | cueto
# Processing Record 35 of Set 24 | inta
# Processing Record 36 of Set 24 | mitsamiouli
# Processing Record 37 of Set 24 | tiznit
# Processing Record 38 of Set 24 | san rafael
# Processing Record 39 of Set 24 | qinhuangdao
# Processing Record 40 of Set 24 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 24 | monticello
# Processing Record 42 of Set 24 | pangai
# Processing Record 43 of Set 24 | port macquarie
# Processing Record 44 of Set 24 | anzhero-sudzhensk
# Processing Record 45 of Set 24 | kitahiroshima
# Processing Record 46 of Set 24 | khandyga
# Processing Record 47 of Set 24 | saint cloud
# Processing Record 48 of Set 24 | roald
# Processing Record 49 of Set 24 | kaoma
# Processing Record 50 of Set 24 | kamiiso
# Processing Record 1 of Set 25 | bagotville
# Processing Record 2 of Set 25 | rawson
# Processing Record 3 of Set 25 | broken hill
# Processing Record 4 of Set 25 | margate
# Processing Record 5 of Set 25 | san javier
# Processing Record 6 of Set 25 | saint-georges
# Processing Record 7 of Set 25 | gjirokaster
# Processing Record 8 of Set 25 | hailar
# Processing Record 9 of Set 25 | poya
# Processing Record 10 of Set 25 | rock springs
# Processing Record 11 of Set 25 | ron
# Processing Record 12 of Set 25 | isla vista
# Processing Record 13 of Set 25 | moree
# Processing Record 14 of Set 25 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 25 | xai-xai
# Processing Record 16 of Set 25 | amapa
# Processing Record 17 of Set 25 | kisangani
# Processing Record 18 of Set 25 | plettenberg bay
# Processing Record 19 of Set 25 | piet retief
# Processing Record 20 of Set 25 | maniago
# Processing Record 21 of Set 25 | harnoli
# Processing Record 22 of Set 25 | thomasville
# Processing Record 23 of Set 25 | atemar
# Processing Record 24 of Set 25 | pemangkat
# Processing Record 25 of Set 25 | sivas
# Processing Record 26 of Set 25 | galveston
# Processing Record 27 of Set 25 | gewane
# Processing Record 28 of Set 25 | kodinsk
# Processing Record 29 of Set 25 | simbahan
# Processing Record 30 of Set 25 | pimentel
# Processing Record 31 of Set 25 | irituia
# Processing Record 32 of Set 25 | walvis bay
# Processing Record 33 of Set 25 | grand-lahou
# Processing Record 34 of Set 25 | shelburne
# Processing Record 35 of Set 25 | koumac
# Processing Record 36 of Set 25 | verkhnevilyuysk
# Processing Record 37 of Set 25 | duldurga
# Processing Record 38 of Set 25 | krasnenkaya
# City not found. Skipping...
# Processing Record 39 of Set 25 | kautokeino
# Processing Record 40 of Set 25 | kohima
# Processing Record 41 of Set 25 | enshi
# Processing Record 42 of Set 25 | gurupa
# Processing Record 43 of Set 25 | lensk
# Processing Record 44 of Set 25 | kolondieba
# Processing Record 45 of Set 25 | imuris
# Processing Record 46 of Set 25 | reconquista
# Processing Record 47 of Set 25 | great falls
# Processing Record 48 of Set 25 | padang
# Processing Record 49 of Set 25 | bhera
# Processing Record 50 of Set 25 | leshukonskoye
# Processing Record 1 of Set 26 | comodoro rivadavia
# Processing Record 2 of Set 26 | karsava
# Processing Record 3 of Set 26 | tezu
# Processing Record 4 of Set 26 | troitsko-pechorsk
# Processing Record 5 of Set 26 | stephenville
# Processing Record 6 of Set 26 | vao
# Processing Record 7 of Set 26 | santa cruz de la palma
# Processing Record 8 of Set 26 | tahoua
# Processing Record 9 of Set 26 | mackenzie
# Processing Record 10 of Set 26 | port hawkesbury
# Processing Record 11 of Set 26 | san quintin
# Processing Record 12 of Set 26 | ballina
# Processing Record 13 of Set 26 | janesville
# Processing Record 14 of Set 26 | guiratinga
# Processing Record 15 of Set 26 | fort nelson
# Processing Record 16 of Set 26 | sur
# Processing Record 17 of Set 26 | sam phran
# Processing Record 18 of Set 26 | kavaratti
# Processing Record 19 of Set 26 | dingle
# Processing Record 20 of Set 26 | husainabad
# Processing Record 21 of Set 26 | wa
# City not found. Skipping...
# Processing Record 22 of Set 26 | kendari
# Processing Record 23 of Set 26 | nagua
# Processing Record 24 of Set 26 | aginskoye
# Processing Record 25 of Set 26 | najran
# Processing Record 26 of Set 26 | poum
# Processing Record 27 of Set 26 | cervo
# Processing Record 28 of Set 26 | ola
# Processing Record 29 of Set 26 | matay
# Processing Record 30 of Set 26 | shunyi
# Processing Record 31 of Set 26 | afsin
# Processing Record 32 of Set 26 | kimbe
# Processing Record 33 of Set 26 | jackson
# Processing Record 34 of Set 26 | meridian
# Processing Record 35 of Set 26 | loreto
# Processing Record 36 of Set 26 | hervey bay
# Processing Record 37 of Set 26 | ipixuna
# Processing Record 38 of Set 26 | nazarovo
# Processing Record 39 of Set 26 | dehloran
# Processing Record 40 of Set 26 | akcakoca
# Processing Record 41 of Set 26 | concordia
# Processing Record 42 of Set 26 | cockburn town
# Processing Record 43 of Set 26 | sumter
# Processing Record 44 of Set 26 | dwarka
# Processing Record 45 of Set 26 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 26 | salisbury
# Processing Record 47 of Set 26 | vrangel
# Processing Record 48 of Set 26 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 26 | koroni
# Processing Record 50 of Set 26 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 27 | broome
# Processing Record 2 of Set 27 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 27 | balaipungut
# Processing Record 4 of Set 27 | sao joao da barra
# Processing Record 5 of Set 27 | viedma
# Processing Record 6 of Set 27 | ofunato
# Processing Record 7 of Set 27 | porto torres
# Processing Record 8 of Set 27 | san luis
# Processing Record 9 of Set 27 | paramonga
# Processing Record 10 of Set 27 | buraydah
# Processing Record 11 of Set 27 | praia da vitoria
# Processing Record 12 of Set 27 | uyemskiy
# Processing Record 13 of Set 27 | berlevag
# Processing Record 14 of Set 27 | calvinia
# Processing Record 15 of Set 27 | arambagh
# Processing Record 16 of Set 27 | prince rupert
# Processing Record 17 of Set 27 | bulawayo
# Processing Record 18 of Set 27 | lucapa
# Processing Record 19 of Set 27 | southbridge
# Processing Record 20 of Set 27 | khani
# Processing Record 21 of Set 27 | port maria
# Processing Record 22 of Set 27 | belaya gora
# Processing Record 23 of Set 27 | qianan
# Processing Record 24 of Set 27 | san patricio
# Processing Record 25 of Set 27 | chibuto
# Processing Record 26 of Set 27 | novyy urengoy
# Processing Record 27 of Set 27 | laguna
# Processing Record 28 of Set 27 | guerrero negro
# Processing Record 29 of Set 27 | benguela
# Processing Record 30 of Set 27 | atar
# Processing Record 31 of Set 27 | menongue
# Processing Record 32 of Set 27 | pontes e lacerda
# Processing Record 33 of Set 27 | qui nhon
# Processing Record 34 of Set 27 | skjervoy
# Processing Record 35 of Set 27 | san jeronimo
# Processing Record 36 of Set 27 | betioky
# Processing Record 37 of Set 27 | nanga eboko
# Processing Record 38 of Set 27 | honiara
# Processing Record 39 of Set 27 | kontagora
# Processing Record 40 of Set 27 | sestri levante
# Processing Record 41 of Set 27 | hambantota
# Processing Record 42 of Set 27 | khandwa
# Processing Record 43 of Set 27 | tsukumi
# Processing Record 44 of Set 27 | meulaboh
# Processing Record 45 of Set 27 | bereda
# Processing Record 46 of Set 27 | shenjiamen
# Processing Record 47 of Set 27 | chumikan
# Processing Record 48 of Set 27 | bada
# Processing Record 49 of Set 27 | christchurch
# Processing Record 50 of Set 27 | qurayyat
# Processing Record 1 of Set 28 | oga
# Processing Record 2 of Set 28 | kalmar
# Processing Record 3 of Set 28 | tairua
# Processing Record 4 of Set 28 | kemijarvi
# Processing Record 5 of Set 28 | manuk mangkaw
# Processing Record 6 of Set 28 | tsabong
# Processing Record 7 of Set 28 | pesochnoye
# Processing Record 8 of Set 28 | custoias
# Processing Record 9 of Set 28 | jiroft
# City not found. Skipping...
# Processing Record 10 of Set 28 | angra
# City not found. Skipping...
# Processing Record 11 of Set 28 | kralendijk
# Processing Record 12 of Set 28 | xuddur
# Processing Record 13 of Set 28 | svetlogorsk
# Processing Record 14 of Set 28 | saint-pierre
# Processing Record 15 of Set 28 | ancud
# Processing Record 16 of Set 28 | deulgaon raja
# Processing Record 17 of Set 28 | tarakan
# Processing Record 18 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 28 | tual
# Processing Record 20 of Set 28 | uroteppa
# City not found. Skipping...
# Processing Record 21 of Set 28 | syamzha
# Processing Record 22 of Set 28 | katobu
# Processing Record 23 of Set 28 | khoy
# Processing Record 24 of Set 28 | hanna
# Processing Record 25 of Set 28 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 28 | pangnirtung
# Processing Record 27 of Set 28 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 28 | jalu
# Processing Record 29 of Set 28 | aberystwyth
# Processing Record 30 of Set 28 | ojinaga
# Processing Record 31 of Set 28 | leh
# Processing Record 32 of Set 28 | mashhad
# Processing Record 33 of Set 28 | chicama
# Processing Record 34 of Set 28 | cerrito
# Processing Record 35 of Set 28 | devils lake
# Processing Record 36 of Set 28 | malinyi
# Processing Record 37 of Set 28 | rybnoye
# Processing Record 38 of Set 28 | alofi
# Processing Record 39 of Set 28 | maumere
# Processing Record 40 of Set 28 | slave lake
# Processing Record 41 of Set 28 | krasnaya zarya
# Processing Record 42 of Set 28 | sao raimundo nonato
# Processing Record 43 of Set 28 | la palma
# Processing Record 44 of Set 28 | sterling
# Processing Record 45 of Set 28 | senekal
# Processing Record 46 of Set 28 | mwense
# Processing Record 47 of Set 28 | richard toll
# City not found. Skipping...
# Processing Record 48 of Set 28 | bonavista
# Processing Record 49 of Set 28 | burnie
# Processing Record 50 of Set 28 | daru
# Processing Record 1 of Set 29 | abu samrah
# Processing Record 2 of Set 29 | kloulklubed
# Processing Record 3 of Set 29 | esmeraldas
# Processing Record 4 of Set 29 | itamaraca
# Processing Record 5 of Set 29 | hays
# Processing Record 6 of Set 29 | kathu
# Processing Record 7 of Set 29 | cleethorpes
# Processing Record 8 of Set 29 | mehamn
# Processing Record 9 of Set 29 | moussoro
# Processing Record 10 of Set 29 | sungairaya
# Processing Record 11 of Set 29 | koslan
# Processing Record 12 of Set 29 | vilcun
# Processing Record 13 of Set 29 | ahipara
# Processing Record 14 of Set 29 | nadbai
# Processing Record 15 of Set 29 | mbour
# Processing Record 16 of Set 29 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 29 | mozarlandia
# Processing Record 18 of Set 29 | asmara
# Processing Record 19 of Set 29 | playas
# Processing Record 20 of Set 29 | marawi
# Processing Record 21 of Set 29 | ambulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Atuona  -9.8000 -139.0333     77.59        78          11
# 1         Sao Filipe  14.8961  -24.4956     77.32        46          70
# 2             Muroto  33.2833  134.1500     44.64        76         100
# 3               Chuy -33.6971  -53.4616     68.36        95          98
# 4    Arraial Do Cabo -22.9661  -42.0278     74.77        85          43
# ..               ...      ...       ...       ...       ...         ...
# 663      Mozarlandia -14.7447  -50.5706     73.04        96          46
# 664           Asmara  15.3333   38.9333     51.53        84          51
# 665           Playas  -2.6333  -80.3833     76.53        74          99
# 666           Marawi   7.9986  124.2928     72.19        75         100
# 667           Ambulu  -8.3450  113.6058     77.22        85          99
#
#      Wind Speed Country       Description
# 0         12.55      PF        light rain
# 1         20.80      CV     broken clouds
# 2         13.96      JP   overcast clouds
# 3          8.48      UY   overcast clouds
# 4          7.23      BR  scattered clouds
# ..          ...     ...               ...
# 663        5.39      BR        light rain
# 664        3.56      ER     broken clouds
# 665        8.21      EC   overcast clouds
# 666        1.28      PH   overcast clouds
# 667        2.93      ID   overcast clouds
#
# [668 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Atuona      PF  -9.8000 -139.0333     77.59        78
# 1         Sao Filipe      CV  14.8961  -24.4956     77.32        46
# 2             Muroto      JP  33.2833  134.1500     44.64        76
# 3               Chuy      UY -33.6971  -53.4616     68.36        95
# 4    Arraial Do Cabo      BR -22.9661  -42.0278     74.77        85
# ..               ...     ...      ...       ...       ...       ...
# 663      Mozarlandia      BR -14.7447  -50.5706     73.04        96
# 664           Asmara      ER  15.3333   38.9333     51.53        84
# 665           Playas      EC  -2.6333  -80.3833     76.53        74
# 666           Marawi      PH   7.9986  124.2928     72.19        75
# 667           Ambulu      ID  -8.3450  113.6058     77.22        85
#
#      Cloudiness  Wind Speed       Description
# 0            11       12.55        light rain
# 1            70       20.80     broken clouds
# 2           100       13.96   overcast clouds
# 3            98        8.48   overcast clouds
# 4            43        7.23  scattered clouds
# ..          ...         ...               ...
# 663          46        5.39        light rain
# 664          51        3.56     broken clouds
# 665          99        8.21   overcast clouds
# 666         100        1.28   overcast clouds
# 667          99        2.93   overcast clouds
#
# [668 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
